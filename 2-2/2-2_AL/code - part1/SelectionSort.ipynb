# %%
# selection sort 
def exchange(x, i, j):
    x[i], x[j] = x[j], x[i]

def selectionSort(x):
    n = len(x)
    for i in range(n-1):
        idx = x.index(min(x[i:]))
        exchange(x, i, idx)
        print('Excahnge! ',x)

x = [10,3,6,2,1]
selectionSort(x)
print(x)
